# %%
#HVRSI system
"""The modified rules:
Entry:
- Stock is a member of the Nasdaq 100
- Close of the stock > 1$
- Close of the stock > SMA(150)
- RSI(2) < 10
- ADX(7) > 20
- Internal Bar Strength < 0.2 == NDX1
- Place a limit order for the next day at todays last close price (cancel the order if it was not filled on the first day)

Exit:
- Current close is greater than yesterdays high,
- Or if 10 days have passed (consider 5)
- Exit next day, market on open

Position sizing:
- 10% per position
- A maximum of 10 positions

// Ranking, note: position score ranks from High to Low
// HV100 Ranking from high to low
HV100 = 100 * StDev(log(Close/Ref(Close,-1)),HV_period) * sqrt(252);
PositionScore = HV100;

"""
# Out:
# 'The modified rules:\nEntry:\n- Stock is a member of the Nasdaq 100\n- Close of the stock > 1$\n- Close of the stock > SMA(150)\n- RSI(2) < 10\n- ADX(7) > 20\n- Internal Bar Strength < 0.2 == NDX1\n- Place a limit order for the next day at todays last close price (cancel the order if it was not filled on the first day)\n\nExit:\n- Current close is greater than yesterdays high,\n- Or if 10 days have passed (consider 5)\n- Exit next day, market on open\n\nPosition sizing:\n- 10% per position\n- A maximum of 10 positions\n\n// Ranking, note: position score ranks from High to Low\n// HV100 Ranking from high to low\nHV100 = 100 * StDev(log(Close/Ref(Close,-1)),HV_period) * sqrt(252);\nPositionScore = HV100;\n\n'

# %%
# %pylab inline
import pandas as pd
from pandas import Series, DataFrame
from scipy import stats
import datetime as dt
import pickle
import talib as ta
from talib import MA_Type
from typing import List
import timeit

import csv
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import io
import requests

def etf_url_spdr(ticker: str) -> str:
    """Create URL string"""
    url = (f'https://www.ssga.com/us/en/individual/etfs/library-content/products/fund-data/etfs/us/holdings-daily-us-en-{ticker.lower()}.xlsx')
    return url

def etf_url_investco(ticker: str) -> str:
    """Create URL string"""
    url = ('https://www.invesco.com/us/financial-products/etfs/holdings/main/holdings/0?audienceType=Investor&action=download&' + f'ticker={ticker}')
    return url

def fetch_etf_spdr(ticker: str) -> pd.DataFrame:
    """Fetch ETF constituents via website"""
    url = etf_url_spdr(ticker)
    res = requests.get(url)
    res.raise_for_status()
    data = io.BytesIO(res.content)
    etf = pd.read_excel(data, header=4, skipfooter=11)
    return etf

def fetch_etf_investco(ticker: str) -> pd.DataFrame:
    """Fetch ETF constituents via website"""
    url = etf_url_investco(ticker)
    res = requests.get(url)
    res.raise_for_status()
    csv = io.StringIO(res.text)
    etf = pd.read_csv(csv)
    return etf

def fetch_weeklyoptions():
    """Fetch ETF constituents via website"""
    url = 'https://marketdata.theocc.com/weekly-options?action=download'
    res = requests.get(url)
    res.raise_for_status()
    csv = io.StringIO(res.text)
    optionslist = list(pd.read_csv(csv).index)
    while nan in optionslist: optionslist.remove(nan) 
    optionslist = [i.strip() for i in optionslist if len(i.strip())>0]
    if 'SYMBOL' in optionslist: optionslist.remove('SYMBOL')
    return optionslist

# %%
from openpyxl import Workbook
from openpyxl import load_workbook
from openpyxl.styles import PatternFill, Border, Side, Alignment, Protection, Font, Fill, Color, NamedStyle
from openpyxl.formatting import Rule
from openpyxl.styles.differential import DifferentialStyle
from openpyxl.formatting.rule import ColorScaleRule, CellIsRule, FormulaRule

# %%
import tiingo
from tiingo import TiingoClient
config = {}
config['session'] = True
#insert your API key here..... 
#config['api_key'] = ""
client = TiingoClient(config)

# %%
def getTicker(sym,d="20150101"):
    return client.get_dataframe(sym, startDate=d)

# %%
#Maarten's function to read data from files
def read_data(ticker: str) -> pd.DataFrame:
    """..."""
    data = pd.read_csv(f'StockData/{ticker}.csv.bz2') 
    data['date'] = pd.to_datetime(data['date'])
    data = data.set_index('date')
    return data

# %%
#Maarten's function to read data adapted to save data
def save_data(ticker: str) -> pd.DataFrame:
    """..."""
    df=stocks[ticker]
    df.to_csv (f'StockData/{ticker}.csv.bz2', header=True, compression='bz2')
    return

# %%
SPYdata = fetch_etf_spdr("SPY")
SP500=list(SPYdata['Ticker'])
SP500.remove("CASH_USD")

# %%
while nan in SP500: SP500.remove(nan) 
SP500=[item.replace(".","-") if "." in item else item for item in SP500]

# %%
DIAdata = fetch_etf_spdr("DIA")
Dow30=list(DIAdata['Ticker'])
Dow30.remove("CASH_USD")
while nan in Dow30: Dow30.remove(nan)

# %%
QQQData = fetch_etf_investco("QQQ")
QQQ=list(QQQData['Holding Ticker'])
QQQ=[item.rstrip() for item in QQQ]
while nan in QQQ: QQQ.remove(nan)

# %%
QQQJData = fetch_etf_investco("QQQJ")
QQQJ=list(QQQJData['Holding Ticker'])
QQQJ=[item.rstrip() for item in QQQJ]
while nan in QQQJ: QQQJ.remove(nan) 

if '9993232D U' in QQQJ: QQQJ.remove('9993232D U')

# %%
#SP500.remove("NBL")
#SP500.remove("VNT")
#SP500.remove("ETFC")
if "CASH_EUR" in SP500: SP500.remove("CASH_EUR")
if "CASH_EUR" in Dow30: Dow30.remove("CASH_EUR")
if "CASH_JPY" in SP500: SP500.remove("CASH_JPY")
#QQQJ.remove('AGPXX')
if '-CASH-' in QQQJ: QQQJ.remove('-CASH-')

# %%
if 'CASH_GBP' in Dow30: Dow30.remove('CASH_GBP')
if 'CASH_GBP' in SP500: SP500.remove('CASH_GBP')
if 'CASH_CHF' in SP500: SP500.remove('CASH_CHF')
if 'CASH_CHF' in Dow30: Dow30.remove('CASH_CHF')

# %%
if 'AGPXX' in QQQJ: QQQJ.remove('AGPXX')

# %%
SP500.remove('VTRS')

# %%
OptionSymbols = fetch_weeklyoptions()

# %%
Today=dt.datetime.today().strftime("%Y%m%d")
Today
# Out:
# '20210819'

# %%
#need to account for holidays when market is closed.....
WeekDay = dt.datetime.today().weekday()
if dt.datetime.now().hour <16 and WeekDay<5:
    print ("current trading day uses yesterday as cutoff")
    LastTradeDay=(dt.datetime.today()-dt.timedelta(1)).strftime("%Y%m%d")
    NextTradeDay=dt.datetime.today().strftime("%Y%m%d")
else:
    print ("after hours, switch to today for cutoff")
    if WeekDay<5: #0-4 = M-F
        LastTradeDay=dt.datetime.today().strftime("%Y%m%d")
    elif WeekDay==5: #5=Sat
        LastTradeDay=(dt.datetime.today()-dt.timedelta(1)).strftime("%Y%m%d")
    elif WeekDay==6: #6 = Sun
        LastTradeDay=(dt.datetime.today()-dt.timedelta(2)).strftime("%Y%m%d")
    if WeekDay<4 or WeekDay == 6:
        NextTradeDay=(dt.datetime.today()+dt.timedelta(1)).strftime("%Y%m%d")
    elif dt.datetime.today().weekday()==4:
        NextTradeDay=(dt.datetime.today()+dt.timedelta(3)).strftime("%Y%m%d")
    elif dt.datetime.today().weekday()==5:
        NextTradeDay=(dt.datetime.today()+dt.timedelta(2)).strftime("%Y%m%d")
print ('LastTradeDay:', LastTradeDay, 'NextTradeDay: ', NextTradeDay)
# Out:
# after hours, switch to today for cutoff
# LastTradeDay: 20210819 NextTradeDay:  20210820

# %%
'''if WeekDay<5: #0-4 = M-F
    LastTradeDay=dt.datetime.today().strftime("%Y%m%d")
elif WeekDay==5: #5=Sat
    LastTradeDay=(dt.datetime.today()-dt.timedelta(1)).strftime("%Y%m%d")
elif WeekDay==6: #6 = Sun
    LastTradeDay=(dt.datetime.today()-dt.timedelta(2)).strftime("%Y%m%d")
LastTradeDay'''
# Out:
# 'if WeekDay<5: #0-4 = M-F\n    LastTradeDay=dt.datetime.today().strftime("%Y%m%d")\nelif WeekDay==5: #5=Sat\n    LastTradeDay=(dt.datetime.today()-dt.timedelta(1)).strftime("%Y%m%d")\nelif WeekDay==6: #6 = Sun\n    LastTradeDay=(dt.datetime.today()-dt.timedelta(2)).strftime("%Y%m%d")\nLastTradeDay'

# %%
'''if WeekDay<4 or WeekDay == 6:
    NextTradeDay=(dt.datetime.today()+dt.timedelta(1)).strftime("%Y%m%d")
elif dt.datetime.today().weekday()==4:
    NextTradeDay=(dt.datetime.today()+dt.timedelta(3)).strftime("%Y%m%d")
elif dt.datetime.today().weekday()==5:
    NextTradeDay=(dt.datetime.today()+dt.timedelta(2)).strftime("%Y%m%d")
NextTradeDay'''
# Out:
# 'if WeekDay<4 or WeekDay == 6:\n    NextTradeDay=(dt.datetime.today()+dt.timedelta(1)).strftime("%Y%m%d")\nelif dt.datetime.today().weekday()==4:\n    NextTradeDay=(dt.datetime.today()+dt.timedelta(3)).strftime("%Y%m%d")\nelif dt.datetime.today().weekday()==5:\n    NextTradeDay=(dt.datetime.today()+dt.timedelta(2)).strftime("%Y%m%d")\nNextTradeDay'

# %%
DayToday = dt.datetime.today().strftime('%A')

# %%
StocksInterest=set(Dow30+QQQ+QQQJ+SP500)
#StocksInterest=set(FrogChamps+SectorSpdrs)

# %%
StocksInterestOptions = set(i for i in StocksInterest if i in OptionSymbols)

# %%
stocks={}

# %%
from ib_insync import *
util.startLoop()  # uncomment this line when in a notebook

# %%
ib = IB()

# %%
'''Insert IB account numbers here
Paper = ""
InheritedIRA=""
GRoth=""
GRollover=""
JointTaxable=""
AllAccounts=[InheritedIRA, GRoth, GRollover, JointTaxable]'''

# %%
def CurrentHoldingsDF(Account):
    df=pd.DataFrame(ib.positions(account=Account))
    if len(df) == 0: 
        return df
    else:
        df.index=[contract.symbol for contract in df["contract"]]
        df['secType']=[contract.secType for contract in df["contract"]]
    return df

# %%
#reads data from CSV files
tickercount=0
newticker=0
SaveData=0
ProblemTicker=[]
for ticker in StocksInterest:
    try:
        #print(ticker)
        df = read_data(ticker)
        stocks[ticker] = df
        tickercount+=1
    except:
        print (ticker, "is new")
        try:
            stocks[ticker]=getTicker(ticker)
            newticker+=1
        except:
            ProblemTicker.append(ticker)
            print (ticker, "has a problem")
print (tickercount, "stocks loaded")
print (newticker, "new stocks added")
print (len(ProblemTicker), "problems encountered")
if newticker>0: SaveData=1
# Out:
# 584 stocks loaded
# 0 new stocks added
# 0 problems encountered

# %%
for item in ProblemTicker:
    if item in StocksInterest:
        StocksInterest.remove(item)

# %%
#Update Data - adjusts for dividends and will load multiple missing days to become current - loads new replacement data for splits
Rejects=[]
tickercount=0
newticker=0
splitticker=0
for ticker in StocksInterest:
    try:
        Lastday=stocks[ticker].index[-1].strftime("%Y%m%d")
        #print (ticker, Lastday)
        if Lastday < LastTradeDay:
            print (ticker, Lastday)
            try:
                NewData=getTicker(ticker, d=Lastday)
                if NewData['divCash'].iloc[-1]>0 and NewData.index[-1].strftime("%Y%m%d")==LastTradeDay: #only adjusts if last day paid dividend (will not correct if multiple new days are added and dividend was not laast day)
                    adjustment=1-(NewData['divCash'].iloc[-1]/NewData['close'].iloc[-1])
                    stocks[ticker][['adjClose','adjHigh','adjLow','adjOpen']]*=adjustment 
                    print(ticker, "adjusted for dividend")
                if NewData['splitFactor'].iloc[-1]>1:
                    stocks[ticker]=getTicker(ticker)
                    splitticker+=1
                    print(ticker, "reloaded for split")
                elif NewData.index[-1].strftime("%Y%m%d")== LastTradeDay:
                    stocks[ticker]=NewData.combine_first(stocks[ticker])
                    tickercount+=1
                else: 
                    Rejects.append(ticker)
            except KeyError:
                print (ticker, "error at tiingo")
                Rejects.append(ticker)
    except KeyError:
        newticker+=1
        stocks[ticker]=getTicker(ticker)
        
print (tickercount, "stocks updated")
print (len(Rejects), "stocks with errors")
print (splitticker, "stocks with splits")
print(newticker, "new stocks loaded")
if newticker>0: SaveData=1
if tickercount>0: SaveData=1
# Out:
# NUAN 20210818
# ZM 20210818
# MRVL 20210818
# APTV 20210818
# JD 20210818
# WLTW 20210818
# GNRC 20210818
# DHI 20210818
# HZNP 20210818
# MAS 20210818
# KIM 20210818
# COF 20210818
# YUM 20210818
# WRK 20210818
# ATVI 20210818
# ROP 20210818
# STT 20210818
# CGNX 20210818
# CGNX adjusted for dividend
# NTRS 20210818
# MTD 20210818
# CBOE 20210818
# RE 20210818
# SYK 20210818
# KLAC 20210818
# EQR 20210818
# AVGO 20210818
# NRG 20210818
# ABT 20210818
# HWM 20210818
# MRK 20210818
# LEG 20210818
# COO 20210818
# INTC 20210818
# SIRI 20210818
# AWK 20210818
# IRM 20210818
# ZS 20210818
# AMCR 20210818
# NVDA 20210818
# PODD 20210818
# SHW 20210818
# SHW adjusted for dividend
# WAT 20210818
# CBRE 20210818
# PPG 20210818
# KR 20210818
# FIS 20210818
# STZ 20210818
# JNJ 20210818
# DIS 20210818
# DISCA 20210818
# DG 20210818
# AON 20210818
# KEYS 20210818
# PEG 20210818
# JPM 20210818
# JKHY 20210818
# EXR 20210818
# CMA 20210818
# LNC 20210818
# NOW 20210818
# TFX 20210818
# UHS 20210818
# NLSN 20210818
# ADP 20210818
# VZ 20210818
# ALL 20210818
# IFF 20210818
# STE 20210818
# VRSN 20210818
# K 20210818
# BILI 20210818
# HLT 20210818
# TFC 20210818
# KDP 20210818
# PBCT 20210818
# DD 20210818
# VRSK 20210818
# TRMB 20210818
# ACN 20210818
# KMI 20210818
# TCOM 20210818
# CSCO 20210818
# ZBH 20210818
# INCY 20210818
# AOS 20210818
# MNST 20210818
# ENPH 20210818
# CTAS 20210818
# TSN 20210818
# MRTX 20210818
# GH 20210818
# FTV 20210818
# PCAR 20210818
# RGEN 20210818
# ZION 20210818
# UPS 20210818
# NDAQ 20210818
# ALLE 20210818
# SSNC 20210818
# ZNGA 20210818
# BAX 20210818
# CRWD 20210818
# ECL 20210818
# SGEN 20210818
# MGM 20210818
# D 20210818
# SEDG 20210818
# HAS 20210818
# CERN 20210818
# IDXX 20210818
# UNP 20210818
# LH 20210818
# BIO 20210818
# MDT 20210818
# COP 20210818
# LUV 20210818
# NWL 20210818
# UNH 20210818
# PEP 20210818
# ZBRA 20210818
# LHX 20210818
# VIAC 20210818
# PFG 20210818
# CARR 20210818
# A 20210818
# WHR 20210818
# BKR 20210818
# SWK 20210818
# AVB 20210818
# CVX 20210818
# KHC 20210818
# PENN 20210818
# ANTM 20210818
# WM 20210818
# DE 20210818
# IPGP 20210818
# PNC 20210818
# RMD 20210818
# GPN 20210818
# QCOM 20210818
# ABMD 20210818
# NOV 20210818
# DHR 20210818
# ARE 20210818
# CFG 20210818
# UDR 20210818
# XOM 20210818
# TWTR 20210818
# REGN 20210818
# ROKU 20210818
# DKNG 20210818
# KSU 20210818
# EIX 20210818
# DLR 20210818
# KMB 20210818
# BBWI 20210818
# BBWI adjusted for dividend
# UA 20210818
# NOC 20210818
# FSLR 20210818
# LBRDK 20210818
# TRV 20210818
# APA 20210818
# ROK 20210818
# BLK 20210818
# LBTYA 20210818
# OKE 20210818
# IBM 20210818
# LNT 20210818
# MTB 20210818
# XYL 20210818
# IEX 20210818
# PLD 20210818
# NLOK 20210818
# BDX 20210818
# EMR 20210818
# RJF 20210818
# ANET 20210818
# MAR 20210818
# DXC 20210818
# SLB 20210818
# VMEO 20210818
# ULTA 20210818
# NXPI 20210818
# SCHW 20210818
# LULU 20210818
# VTR 20210818
# FFIV 20210818
# BRK-B 20210818
# ETN 20210818
# HUM 20210818
# EQIX 20210818
# MAA 20210818
# ALK 20210818
# PKI 20210818
# PNW 20210818
# GPS 20210818
# PAYC 20210818
# TEAM 20210818
# AZO 20210818
# ENTG 20210818
# SIVB 20210818
# DFS 20210818
# LIN 20210818
# MRO 20210818
# RUN 20210818
# ADBE 20210818
# NTAP 20210818
# TTD 20210818
# RTX 20210818
# RTX adjusted for dividend
# DVA 20210818
# RPRX 20210818
# RPRX adjusted for dividend
# MSCI 20210818
# SYF 20210818
# EBAY 20210818
# ASML 20210818
# NKE 20210818
# CMCSA 20210818
# DISCK 20210818
# RL 20210818
# LMT 20210818
# CCL 20210818
# NUE 20210818
# RF 20210818
# TXG 20210818
# JCI 20210818
# FLT 20210818
# CLX 20210818
# MU 20210818
# BKNG 20210818
# NVR 20210818
# ABC 20210818
# REG 20210818
# NICE 20210818
# CVS 20210818
# DOW 20210818
# L 20210818
# MHK 20210818
# FCX 20210818
# CI 20210818
# MOS 20210818
# MDB 20210818
# SO 20210818
# IT 20210818
# WDAY 20210818
# TMUS 20210818
# MSI 20210818
# KMX 20210818
# BMY 20210818
# LYV 20210818
# AMT 20210818
# BIIB 20210818
# DUK 20210818
# DPZ 20210818
# ALNY 20210818
# AMZN 20210818
# MLM 20210818
# MKC 20210818
# CB 20210818
# BEN 20210818
# UNM 20210818
# HAL 20210818
# MRNA 20210818
# APD 20210818
# CHKP 20210818
# CINF 20210818
# SBUX 20210818
# PKG 20210818
# EW 20210818
# RGLD 20210818
# BA 20210818
# MXIM 20210818
# NWS 20210818
# HST 20210818
# PPD 20210818
# CNP 20210818
# KEY 20210818
# CAG 20210818
# LYB 20210818
# AJG 20210818
# PSX 20210818
# DVN 20210818
# CTXS 20210818
# LKQ 20210818
# SNY 20210818
# AMGN 20210818
# CAH 20210818
# WYNN 20210818
# AAP 20210818
# DDOG 20210818
# OTEX 20210818
# CTVA 20210818
# TDG 20210818
# LBTYK 20210818
# HPQ 20210818
# ITW 20210818
# GDS 20210818
# RYAAY 20210818
# SRPT 20210818
# FMC 20210818
# FB 20210818
# NEM 20210818
# IPG 20210818
# FTNT 20210818
# LLY 20210818
# EXPE 20210818
# GE 20210818
# GL 20210818
# AEP 20210818
# ANSS 20210818
# CMG 20210818
# MSFT 20210818
# HPE 20210818
# BWA 20210818
# GRMN 20210818
# MKTX 20210818
# EOG 20210818
# TTWO 20210818
# GM 20210818
# DAL 20210818
# ETSY 20210818
# ATO 20210818
# PGR 20210818
# HSY 20210818
# HSY adjusted for dividend
# WDC 20210818
# ETR 20210818
# AFL 20210818
# OXY 20210818
# PVH 20210818
# SEE 20210818
# EMN 20210818
# FOX 20210818
# PEGA 20210818
# BBY 20210818
# MMC 20210818
# SPGI 20210818
# LRCX 20210818
# HES 20210818
# FDX 20210818
# ROST 20210818
# BSX 20210818
# NVCR 20210818
# NFLX 20210818
# NWSA 20210818
# DRE 20210818
# UAA 20210818
# MO 20210818
# EXPD 20210818
# FIVN 20210818
# PH 20210818
# PTC 20210818
# GD 20210818
# OTIS 20210818
# OTIS adjusted for dividend
# NTES 20210818
# HRL 20210818
# BK 20210818
# O 20210818
# HD 20210818
# ES 20210818
# AXP 20210818
# BIDU 20210818
# WIX 20210818
# CCI 20210818
# PM 20210818
# MDLZ 20210818
# SNA 20210818
# SNA adjusted for dividend
# JAZZ 20210818
# CNC 20210818
# ALGN 20210818
# NBIX 20210818
# CTLT 20210818
# SRE 20210818
# FISV 20210818
# LW 20210818
# AKAM 20210818
# PSA 20210818
# COUP 20210818
# HBAN 20210818
# MCD 20210818
# ISRG 20210818
# ALB 20210818
# ESS 20210818
# XEL 20210818
# GILD 20210818
# ZTS 20210818
# PWR 20210818
# CHTR 20210818
# WY 20210818
# TMO 20210818
# TPR 20210818
# C 20210818
# WRB 20210818
# ODFL 20210818
# HBI 20210818
# GWW 20210818
# LOW 20210818
# CDNS 20210818
# ABBV 20210818
# FANG 20210818
# PPL 20210818
# CE 20210818
# CZR 20210818
# NCLH 20210818
# TAP 20210818
# AZN 20210818
# OKTA 20210818
# BGNE 20210818
# DISH 20210818
# WMT 20210818
# MET 20210818
# MTCH 20210818
# GOOGL 20210818
# KO 20210818
# VMC 20210818
# TSCO 20210818
# PFE 20210818
# PHM 20210818
# MPWR 20210818
# OMC 20210818
# MCHP 20210818
# MCHP adjusted for dividend
# PAYX 20210818
# AME 20210818
# DOX 20210818
# IP 20210818
# CSX 20210818
# CPB 20210818
# MCK 20210818
# MCO 20210818
# MCO adjusted for dividend
# LVS 20210818
# STNE 20210818
# CTSH 20210818
# CTSH adjusted for dividend
# NEE 20210818
# AMP 20210818
# TER 20210818
# YNDX 20210818
# DRI 20210818
# T 20210818
# USB 20210818
# CHRW 20210818
# JBHT 20210818
# GOOG 20210818
# FRC 20210818
# FBHS 20210818
# MMM 20210818
# POOL 20210818
# BF-B 20210818
# SPG 20210818
# AAL 20210818
# ICE 20210818
# TXN 20210818
# PDD 20210818
# PNR 20210818
# WBA 20210818
# WBA adjusted for dividend
# SJM 20210818
# GIS 20210818
# ORLY 20210818
# GS 20210818
# IQ 20210818
# NI 20210818
# BMRN 20210818
# CF 20210818
# ROL 20210818
# TDY 20210818
# OLED 20210818
# INFO 20210818
# DOV 20210818
# TXT 20210818
# CDW 20210818
# FITB 20210818
# QDEL 20210818
# LOGI 20210818
# EXC 20210818
# WU 20210818
# AMAT 20210818
# WELL 20210818
# PG 20210818
# EFX 20210818
# IR 20210818
# AAPL 20210818
# SPLK 20210818
# CME 20210818
# J 20210818
# WFC 20210818
# CL 20210818
# HOLX 20210818
# SBAC 20210818
# CMI 20210818
# CMI adjusted for dividend
# HCA 20210818
# NDSN 20210818
# HIG 20210818
# TYL 20210818
# MA 20210818
# EL 20210818
# PRU 20210818
# TROW 20210818
# RCL 20210818
# INTU 20210818
# CPRT 20210818
# AES 20210818
# PCTY 20210818
# PYPL 20210818
# QRVO 20210818
# IQV 20210818
# ON 20210818
# SNPS 20210818
# VRTX 20210818
# LUMN 20210818
# WEC 20210818
# MASI 20210818
# GLW 20210818
# BYND 20210818
# ADM 20210818
# FRT 20210818
# MELI 20210818
# ADI 20210818
# CMS 20210818
# ADSK 20210818
# DXCM 20210818
# TGT 20210818
# LEN 20210818
# XLNX 20210818
# EA 20210818
# ORCL 20210818
# AIZ 20210818
# AMD 20210818
# BXP 20210818
# FE 20210818
# CAT 20210818
# CRL 20210818
# DOCU 20210818
# URI 20210818
# V 20210818
# DLTR 20210818
# AEE 20210818
# RHI 20210818
# AIG 20210818
# STX 20210818
# ED 20210818
# PXD 20210818
# FAST 20210818
# COG 20210818
# GPC 20210818
# RSG 20210818
# VNO 20210818
# SWKS 20210818
# HSIC 20210818
# OGN 20210818
# SYY 20210818
# XRAY 20210818
# TJX 20210818
# WMB 20210818
# CRM 20210818
# WST 20210818
# AVY 20210818
# BAC 20210818
# CHD 20210818
# BR 20210818
# APH 20210818
# LDOS 20210818
# ILMN 20210818
# COST 20210818
# DTE 20210818
# TEL 20210818
# TEL adjusted for dividend
# PEAK 20210818
# MPC 20210818
# IAC 20210818
# TSLA 20210818
# F 20210818
# HII 20210818
# BLL 20210818
# JNPR 20210818
# DGX 20210818
# PTON 20210818
# PRGO 20210818
# MS 20210818
# VFC 20210818
# HON 20210818
# FOXA 20210818
# WAB 20210818
# EVRG 20210818
# EVRG adjusted for dividend
# VLO 20210818
# UAL 20210818
# NSC 20210818
# IVZ 20210818
# TT 20210818
# 584 stocks updated
# 0 stocks with errors
# 0 stocks with splits
# 0 new stocks loaded

# %%
Rejects
# Out:
# []

# %%
#Update Rejects - May be repeated until all Rejects are updated
tickercount=0
for ticker in Rejects: #StocksInterest:
    Lastday=stocks[ticker].index[-1].strftime("%Y%m%d")
    #print (ticker, Lastday)
    if Lastday < LastTradeDay:
        try:
            NewData=getTicker(ticker, d=Lastday)
#            stocks[ticker]=pd.concat([stocks[ticker],NewData] )#consider iloc [1:]of NewData
            if NewData['divCash'].iloc[-1]>0 and NewData.index[-1].strftime("%Y%m%d")==LastTradeDay:
                adjustment=1-(NewData['divCash'].iloc[-1]/NewData['close'].iloc[-1])
                stocks[ticker][['adjClose','adjHigh','adjLow','adjOpen']]*=adjustment 
                print(ticker, "adjusted for dividend")
            if NewData.index[-1].strftime("%Y%m%d")== LastTradeDay:
                stocks[ticker]=NewData.combine_first(stocks[ticker])
                tickercount+=1
                Rejects.remove(ticker)
            if int(NewData.index[-1].strftime("%Y%m%d")) > int(Lastday):
                stocks[ticker]=NewData.combine_first(stocks[ticker])
                print (ticker, "added data - incomplete")
        except KeyError:
            print (ticker, "error at tiingo")
            Rejects.append(ticker)
print (tickercount, "stocks updated")
print (len(Rejects), "stocks with errors")
if tickercount>0: SaveData=1
# Out:
# 0 stocks updated
# 0 stocks with errors

# %%
#Update Data - cycles automaticlly through rejects for x cycles or until none left before asking about continuing 
x=100
tickercount=0
passcount=0
while len(Rejects)>0:
    passcount+=1
    for ticker in Rejects:
        Lastday=stocks[ticker].index[-1].strftime("%Y%m%d")
        print (ticker, Lastday)
        if Lastday < LastTradeDay:
            try:
                if NewData['divCash'].iloc[-1]>0 and NewData.index[-1].strftime("%Y%m%d")==LastTradeDay:
                    adjustment=1-(NewData['divCash'].iloc[-1]/NewData['close'].iloc[-1])
                    stocks[ticker][['adjClose','adjHigh','adjLow','adjOpen']]*=adjustment 
                    print(ticker, "adjusted for dividend")
                if NewData.index[-1].strftime("%Y%m%d")== LastTradeDay:
                    stocks[ticker]=NewData.combine_first(stocks[ticker])
                    tickercount+=1
                    Rejects.remove(ticker)
                if int(NewData.index[-1].strftime("%Y%m%d")) > int(Lastday):
                    stocks[ticker]=NewData.combine_first(stocks[ticker])
                    print (ticker, "added data - incomplete")
            except KeyError:
                pass
    if passcount % x == 0: 
        c=input(f"We have done {passcount} checks with {len(Rejects)} still with errors. Continue checking?")
        if c=="y" or c=="Y": pass
        else: break
print (tickercount, "stocks updated")
print (len(Rejects), "stocks with errors")
if tickercount>0: SaveData=1
# Out:
# 0 stocks updated
# 0 stocks with errors

# %%
closes=pd.DataFrame()
closes.name="close"
highs=pd.DataFrame()
highs.name="high"
lows=pd.DataFrame()
lows.name="low"
opens=pd.DataFrame()
opens.name="open"
for item in sorted(StocksInterest):
    closes[item]=stocks[item]["adjClose"]
    opens[item]=stocks[item]["adjOpen"]
    highs[item]=stocks[item]["adjHigh"]
    lows[item]=stocks[item]["adjLow"]

# %%
closes.head(3)
# Out:
#                                    A        AAL         AAP       AAPL  \
# date
# 2015-01-02 00:00:00+00:00  38.244533  51.072326  155.664161  24.779731
# 2015-01-05 00:00:00+00:00  37.527920  51.039169  153.612331  24.081646
# 2015-01-06 00:00:00+00:00  36.943314  50.248121  153.504340  24.083913
#
#                                 ABBV        ABC   ABMD        ABT        ACN  \
# date
# 2015-01-02 00:00:00+00:00  49.872321  80.935140  37.31  39.559915  79.240132
# 2015-01-05 00:00:00+00:00  48.933761  80.246216  37.07  39.568726  77.902219
# 2015-01-06 00:00:00+00:00  48.691552  80.684622  36.13  39.119381  77.340296
#
#                             ADBE  ...        XYL    YNDX        YUM  \
# date                              ...
# 2015-01-02 00:00:00+00:00  72.34  ...  34.965720  18.370  45.840440
# 2015-01-05 00:00:00+00:00  71.98  ...  32.789545  17.405  44.909058
# 2015-01-06 00:00:00+00:00  70.53  ...  32.596719  17.530  44.357833
#
#                                   ZBH   ZBRA       ZION  ZM  ZNGA  ZS  \
# date
# 2015-01-02 00:00:00+00:00  107.093616  77.43  25.182534 NaN  2.73 NaN
# 2015-01-05 00:00:00+00:00  111.088582  76.34  24.238968 NaN  2.71 NaN
# 2015-01-06 00:00:00+00:00  110.146912  75.79  23.313205 NaN  2.70 NaN
#
#                                  ZTS
# date
# 2015-01-02 00:00:00+00:00  41.458558
# 2015-01-05 00:00:00+00:00  41.209673
# 2015-01-06 00:00:00+00:00  40.807627
#
# [3 rows x 584 columns]

# %%
closes.tail()
# Out:
#                                 A    AAL     AAP    AAPL    ABBV     ABC  \
# date
# 2021-08-13 00:00:00+00:00  159.23  19.84  206.43  149.10  116.48  119.57
# 2021-08-16 00:00:00+00:00  162.07  19.76  212.26  151.12  118.41  120.07
# 2021-08-17 00:00:00+00:00  160.91  19.34  207.77  150.19  119.66  120.94
# 2021-08-18 00:00:00+00:00  163.02  19.14  207.62  146.36  117.29  118.58
# 2021-08-19 00:00:00+00:00  167.67  18.73  208.37  146.70  117.93  119.26
#
#                              ABMD     ABT     ACN    ADBE  ...     XYL   YNDX  \
# date                                                       ...
# 2021-08-13 00:00:00+00:00  321.65  123.06  323.45  637.31  ...  131.53  67.94
# 2021-08-16 00:00:00+00:00  323.93  124.66  328.25  636.94  ...  132.93  69.51
# 2021-08-17 00:00:00+00:00  328.56  125.69  329.30  635.01  ...  131.80  69.07
# 2021-08-18 00:00:00+00:00  330.80  123.93  324.55  626.77  ...  130.27  68.58
# 2021-08-19 00:00:00+00:00  333.35  125.72  328.25  637.66  ...  130.25  68.25
#
#                               YUM     ZBH    ZBRA   ZION      ZM  ZNGA  \
# date
# 2021-08-13 00:00:00+00:00  134.96  146.09  571.07  55.41  355.24  8.27
# 2021-08-16 00:00:00+00:00  135.12  146.57  572.89  55.04  348.41  8.14
# 2021-08-17 00:00:00+00:00  134.92  147.86  562.68  54.36  345.54  8.21
# 2021-08-18 00:00:00+00:00  134.39  144.38  557.18  53.64  340.93  8.20
# 2021-08-19 00:00:00+00:00  133.96  144.12  562.72  53.17  332.38  8.37
#
#                                ZS     ZTS
# date
# 2021-08-13 00:00:00+00:00  245.15  201.48
# 2021-08-16 00:00:00+00:00  243.43  204.78
# 2021-08-17 00:00:00+00:00  241.47  206.60
# 2021-08-18 00:00:00+00:00  242.54  203.33
# 2021-08-19 00:00:00+00:00  244.88  206.44
#
# [5 rows x 584 columns]

# %%
#save data to disk
Tickercount=0
if SaveData==1: 
    for ticker in StocksInterest:
    #    print(ticker)
        Tickercount+=1
        save_data(ticker)
print(Tickercount, "stocks saved to disk")
# Out:
# 584 stocks saved to disk

# %%
def MACalc(df,n):
    ReturnDF=closes.rolling(window=n).mean()
    ReturnDF.name='MA'+str(n)
    return ReturnDF

# %%
def HVCalc (df,n):
    V=(np.log(df/df.shift()))
    ReturnDF=100 * V.rolling(window=n).std() * sqrt(252)
    ReturnDF.name='HV'+str(n)
    return ReturnDF

# %%
def ADXCalc (df, n):
    ReturnDF=pd.DataFrame()
    ReturnDF.name='ADX'+str(n)
    for item in df.columns:
        ReturnDF[item]=round(ta.ADX(highs[item], lows[item], closes[item], timeperiod=n),2)
    return ReturnDF

# %%
def IBSCalc(): #gives percentage placement of closing price within range of today's bar
    df = (closes-lows)/(highs-lows)
    df.name='IBS'
    return df

# %%
def RSICalc (df, n):
    ReturnDF=pd.DataFrame()
    ReturnDF.name='RSI'+str(n)
    for item in df.columns:
        ReturnDF[item]=round(ta.RSI(df[item], n),2)
    return ReturnDF

# %%
IBS1=pd.DataFrame()
IBS1=IBSCalc()
MA150=MACalc(closes,150)
HV100=HVCalc(closes, 100)
ADX7 = ADXCalc(closes, 7)
RSI2=RSICalc (closes, 2)

# %%
def HvRSICompleteTable(df, Portfolio=30000, Number=10):
    df['close']=closes.iloc[-1]
    df['high']=highs.iloc[-1]
    df['150dMA']=MA150.iloc[-1]
    df['C>150']=df['close']>df['150dMA']
    df['RSI2']=RSI2.iloc[-1]
    df["ADX7"]=ADX7.iloc[-1]
    df['IBS1']=IBS1.iloc[-1]
    df["HV100"]=HV100.iloc[-1]
    return df

# %%
HvRSISpyComplete=pd.DataFrame(index=SP500)
HvRSISpyComplete=HvRSICompleteTable(HvRSISpyComplete).sort_values(by=['HV100'], ascending=False)
export_csv = HvRSISpyComplete.to_csv (f'StockReports/HvRSISpyComplete{Today}.csv', header=True)
HvRSISpyComplete
# Out:
#        close      high      150dMA  C>150   RSI2   ADX7      IBS1       HV100
# GE     99.42  100.8200   21.938846   True   1.49  60.00  0.369369  327.232400
# NVDA  197.98  204.9500  549.654532  False  67.96  68.83  0.597807  225.007390
# MRNA  375.53  394.9199  204.415500   True  20.97  31.50  0.026607   73.987759
# BIIB  338.62  347.7900  300.534200   True  20.94  32.15  0.092977   59.443834
# ENPH  162.89  166.4900  164.260600  False  13.20  34.48  0.421222   59.269538
# ...      ...       ...         ...    ...    ...    ...       ...         ...
# JNJ   178.57  179.3269  165.744601   True  64.78  47.76  0.767601   12.364255
# PEP   158.91  159.4200  143.611069   True  77.50  32.43  0.859890   12.267355
# KO     56.86   56.9800   53.012062   True  48.81  25.90  0.883495   11.403054
# VZ     55.37   55.6600   56.381855  False  15.65  20.67  0.382979   10.272835
# OGN    34.10   34.5668         NaN  False  51.36  43.04  0.699188         NaN
#
# [504 rows x 8 columns]

# %%
def HvRSITable(df, Portfolio=30000, Number=10):
    df['close']=closes.iloc[-1]
    df['high']=highs.iloc[-1]
    df['150dMA']=MA150.iloc[-1]
    df['C>150']=df['close']>df['150dMA']
    df['RSI2']=RSI2.iloc[-1]
    df["ADX7"]=ADX7.iloc[-1]
    df['IBS1']=IBS1.iloc[-1]
    df["HV100"]=HV100.iloc[-1]
    df['Size']=round((Portfolio/Number)/df['close'],0)
    df['Cost']=df['Size']*df['close']
    R1=df[(df['ADX7']>20) & (df['RSI2']<10) & (df['IBS1']<.20) & (df['C>150']==True)]
    R2 = R1.drop(['C>150'], axis=1)
    return R2

# %%
HvRSISpy=pd.DataFrame(index=SP500)
HvRSISpy=HvRSITable(HvRSISpy).sort_values(by=['HV100'], ascending=False)
export_csv = HvRSISpy.to_csv (f'StockReports/HvRSISpy{Today}.csv', header=True)
HvRSISpy
# Out:
#       close     high      150dMA  RSI2   ADX7      IBS1      HV100   Size  \
# UAA   22.61   23.205   21.897800  0.76  47.03  0.156028  39.606315  133.0
# UA    19.05   19.595   18.554333  0.70  45.84  0.068376  38.249958  157.0
# IPG   36.10   36.919   30.604511  2.45  40.72  0.017986  29.652061   83.0
# TXT   69.84   71.415   61.050278  1.28  29.49  0.147497  25.909528   43.0
# PPG  161.14  163.770  159.909039  1.47  26.10  0.070671  24.462479   19.0
# WAB   85.49   88.320   80.288195  1.53  39.75  0.050336  23.657356   35.0
# J    131.93  133.720  128.497233  5.31  22.72  0.186364  22.179396   23.0
# TDY  446.03  451.560  416.260867  3.78  23.92  0.159574  20.954571    7.0
# TGT  245.41  249.530  216.130821  2.77  39.37  0.196881  18.732847   12.0
# ADM   59.32   60.730   59.226427  4.30  38.87  0.132308  18.474418   51.0
# IFF  149.40  151.350  139.934760  2.02  34.74  0.062500  17.645860   20.0
# CNP   25.92   26.670   23.458950  4.39  46.50  0.056604  17.084014  116.0
#
#         Cost
# UAA  3007.13
# UA   2990.85
# IPG  2996.30
# TXT  3003.12
# PPG  3061.66
# WAB  2992.15
# J    3034.39
# TDY  3122.21
# TGT  2944.92
# ADM  3025.32
# IFF  2988.00
# CNP  3006.72

# %%
HvRSIQQQ=pd.DataFrame(index=QQQ)
HvRSIQQQ=HvRSITable(HvRSIQQQ).sort_values(by=['HV100'], ascending=False)
export_csv = HvRSIQQQ.to_csv (f'StockReports/HvRSIQQQ{Today}.csv', header=True)
HvRSIQQQ
# Out:
# Empty DataFrame
# Columns: [close, high, 150dMA, RSI2, ADX7, IBS1, HV100, Size, Cost]
# Index: []

# %%
#connect to paper to transmit HVRSI signals
LivePaper = input("Live or Paper (l/p)?")
if LivePaper == 'l':
    IBPort = 7496
    TradeAccount = JointTaxable
    Broker = "IB"
else:
    print ("Trading paper account")
    IBPort = 7497
    TradeAccount = Paper
    Broker = "IBPaper"
# Out:
# Live or Paper (l/p)?p
# Trading paper account

# %%
ib.connect('127.0.0.1', IBPort, clientId=0)
# Out:
# <IB connected to 127.0.0.1:7497 clientId=0>

# %%
if IBPort == 7497:
    PaperPositions=CurrentHoldingsDF(Paper)
    #OmitList = ['GBTC' , 'SPY' , 'ETHE']
else:
    PaperPositions=CurrentHoldingsDF(JointTaxable)
    #OmitList = ['GBTC' , 'SPY' , 'ETHE', 'AMC', 'WISH', 'EXPR', 'BTU', 'SPCE']

if len(PaperPositions)>0:
    PaperHoldings = PaperPositions[PaperPositions['secType']=='STK']
else:
    PaperHoldings=PaperPositions

# %%
PaperHoldings
# Out:
#        account                                           contract  position  \
# GBTC  DU970594  Stock(conId=349966059, symbol='GBTC', exchange...      10.0
# SPY   DU970594  Stock(conId=756733, symbol='SPY', exchange='AR...      10.0
# ETHE  DU970594  Stock(conId=372707395, symbol='ETHE', exchange...     100.0
# XLNX  DU970594  Stock(conId=276222, symbol='XLNX', exchange='N...      21.0
# MRVL  DU970594  Stock(conId=483492393, symbol='MRVL', exchange...      52.0
# ASML  DU970594  Stock(conId=117902840, symbol='ASML', exchange...       4.0
# KLAC  DU970594  Stock(conId=270957, symbol='KLAC', exchange='N...       9.0
# ALGN  DU970594  Stock(conId=11459264, symbol='ALGN', exchange=...       4.0
# DOCU  DU970594  Stock(conId=316073742, symbol='DOCU', exchange...      11.0
# CPRT  DU970594  Stock(conId=4728523, symbol='CPRT', exchange='...      21.0
# NXPI  DU970594  Stock(conId=77791077, symbol='NXPI', exchange=...      15.0
#
#          avgCost secType
# GBTC   32.938130     STK
# SPY   337.178230     STK
# ETHE   20.152703     STK
# XLNX  140.919879     STK
# MRVL   57.549936     STK
# ASML  763.340614     STK
# KLAC  315.037017     STK
# ALGN  671.120764     STK
# DOCU  284.745042     STK
# CPRT  143.344781     STK
# NXPI  201.013551     STK

# %%
OmitList = []
try:
    with open(f'OmitList{Broker}.csv', newline='') as f:
        reader = csv.reader(f)
        for row in reader:
            for i in row:
                OmitList.append(i)
except:
    print("Error")

print ("Current OmitList:", OmitList)
# Out:
# Current OmitList: ['GBTC', 'ETHE', 'SPY']

# %%
#print ("Current OmitList:", OmitList)
OmitAdd='y'
while OmitAdd == 'y':
    OmitAdd = input ("Do you wish to add to the OmitList? ")
    if OmitAdd == 'y':
        AddSymbol = input ("Which symbol? ")
        OmitList.append(AddSymbol)
        print (AddSymbol, "added to OmitList")
# Out:
# Do you wish to add to the OmitList? n

# %%
print ("Current OmitList:", OmitList)
OmitDelete='y'
while OmitDelete == 'y':
    OmitDelete = input ("Do you wish to delete from the OmitList? ")
    if OmitDelete == 'y':
        DeleteSymbol = input ("Which symbol? ")
        OmitList.remove(DeleteSymbol)
        print (DeleteSymbol, "removed from OmitList")

print ("Current OmitList:", OmitList)
# Out:
# Current OmitList: ['GBTC', 'ETHE', 'SPY']
# Do you wish to delete from the OmitList? n
# Current OmitList: ['GBTC', 'ETHE', 'SPY']

# %%
with open(f'OmitList{Broker}.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(OmitList)

# %%
HvRSIHoldings =[item for item in PaperHoldings.index if item not in OmitList]
HvRSIHoldings
# Out:
# ['XLNX', 'MRVL', 'ASML', 'KLAC', 'ALGN', 'DOCU', 'CPRT', 'NXPI']

# %%
NewHvRSI = [item for item in HvRSIQQQ.index if item not in HvRSIHoldings]
NewHvRSI
# Out:
# []

# %%
TheFileName = "/Users/glennosborne/Documents/Python/TradeLog/HVRSITrades.csv"
HeaderLine=['SignalDate', 'Symbol', 'Size', '150dMA', 'RSI2', 'ADX7', 'IBS1', 'HV100']

def CreateLogFile(header):
    with open(TheFileName, 'a', newline='') as myfile:
        wr = csv.writer(myfile)
        wr.writerow(header)
    return

CreateLogFile(HeaderLine)

def LogData():
    DataLine=['Date', 'Symbol', 'Size', 'Action', 'FillPrice'] #to collect entries and exits
    with open(TheFileName, 'a', newline='') as myfile:
        wr = csv.writer(myfile)
        wr.writerow(DataLine)
    return

# %%
#read trade fills from IB and save as pickle
TradeFillsDF=util.df(ib.fills()) #Seems to read both paper and live while connected only to paper!!!!!
if IBPort == 7497:
    outfile = open(f"StockReports/Trades/PaperTodaysTrades{Today}",'wb')
    pickle.dump(TradeFillsDF,outfile)
    outfile.close()
TradeFillsDF
# Out:
#                                              contract  \
# 0   Future(conId=446091387, symbol='MYM', lastTrad...
# 1   Stock(conId=265768, symbol='ADBE', exchange='I...
# 2   Stock(conId=6735, symbol='EFX', exchange='NYSE...
# 3   Stock(conId=268960158, symbol='DXC', exchange=...
# 4   Stock(conId=316073742, symbol='DOCU', exchange...
# 5   Stock(conId=39195389, symbol='POOL', exchange=...
# 6   Stock(conId=10291, symbol='NKE', exchange='NYS...
# 7   Future(conId=446091387, symbol='MYM', lastTrad...
# 8   Future(conId=446091387, symbol='MYM', lastTrad...
# 9   Future(conId=446091387, symbol='MYM', lastTrad...
# 10  Future(conId=446091387, symbol='MYM', lastTrad...
# 11  Future(conId=446091387, symbol='MYM', lastTrad...
# 12  Future(conId=446091387, symbol='MYM', lastTrad...
# 13  Future(conId=446091387, symbol='MYM', lastTrad...
# 14  Future(conId=446091387, symbol='MYM', lastTrad...
# 15  Future(conId=446091387, symbol='MYM', lastTrad...
# 16  Future(conId=446091387, symbol='MYM', lastTrad...
# 17  Future(conId=446091387, symbol='MYM', lastTrad...
# 18  Future(conId=446091387, symbol='MYM', lastTrad...
# 19  Future(conId=446091387, symbol='MYM', lastTrad...
# 20  Future(conId=446091387, symbol='MYM', lastTrad...
# 21  Future(conId=446091387, symbol='MYM', lastTrad...
# 22  Future(conId=446091387, symbol='MYM', lastTrad...
# 23  Future(conId=446091387, symbol='MYM', lastTrad...
# 24  Future(conId=446091387, symbol='MYM', lastTrad...
# 25  Stock(conId=4726368, symbol='ANSS', exchange='...
# 26  Stock(conId=276222, symbol='XLNX', exchange='I...
# 27  Stock(conId=270957, symbol='KLAC', exchange='I...
# 28  Stock(conId=11459264, symbol='ALGN', exchange=...
# 29  Stock(conId=5552, symbol='CDNS', exchange='ISL...
# 30  Stock(conId=117902840, symbol='ASML', exchange...
# 31  Stock(conId=316073742, symbol='DOCU', exchange...
# 32  Stock(conId=77791077, symbol='NXPI', exchange=...
# 33  Stock(conId=483492393, symbol='MRVL', exchange...
# 34  Stock(conId=4726368, symbol='ANSS', exchange='...
# 35  Stock(conId=5552, symbol='CDNS', exchange='ISL...
#
#                                             execution  \
# 0   Execution(execId='0001911f.611d8b4b.01.01', ti...
# 1   Execution(execId='00013d66.611e37cc.01.01', ti...
# 2   Execution(execId='00012dbf.611e325b.01.01', ti...
# 3   Execution(execId='00012dbf.611e3682.01.01', ti...
# 4   Execution(execId='00013d04.611e216e.01.01', ti...
# 5   Execution(execId='00013800.611e6d71.01.01', ti...
# 6   Execution(execId='00012dc6.611e3e3f.01.01', ti...
# 7   Execution(execId='0001911f.611d8c29.01.01', ti...
# 8   Execution(execId='0001911f.611d8d3e.01.01', ti...
# 9   Execution(execId='0001911f.611d8d4b.01.01', ti...
# 10  Execution(execId='0001911f.611d8e18.01.01', ti...
# 11  Execution(execId='0001911f.611d8e61.01.01', ti...
# 12  Execution(execId='0001911f.611d8e7c.01.01', ti...
# 13  Execution(execId='0001911f.611d8f09.01.01', ti...
# 14  Execution(execId='0001911f.611d8f1a.01.01', ti...
# 15  Execution(execId='0001911f.611d8f8e.01.01', ti...
# 16  Execution(execId='0001911f.611d9005.01.01', ti...
# 17  Execution(execId='0001911f.611d9006.01.01', ti...
# 18  Execution(execId='0001911f.611d9026.01.01', ti...
# 19  Execution(execId='0001911f.611d9055.01.01', ti...
# 20  Execution(execId='0001911f.611d9286.01.01', ti...
# 21  Execution(execId='0001911f.611d9306.01.01', ti...
# 22  Execution(execId='0001911f.611d9399.01.01', ti...
# 23  Execution(execId='0001911f.611d9dd2.01.01', ti...
# 24  Execution(execId='0001911f.611d9e09.01.01', ti...
# 25  Execution(execId='0000ddc2.611e9227.01.01', ti...
# 26  Execution(execId='0000e22a.616a85b3.01.01', ti...
# 27  Execution(execId='0000e22a.616a8614.01.01', ti...
# 28  Execution(execId='0000e0d5.6175855b.01.01', ti...
# 29  Execution(execId='0000e0d5.61758637.01.01', ti...
# 30  Execution(execId='0000e0d5.61758d71.01.01', ti...
# 31  Execution(execId='0000e0d5.61758d85.01.01', ti...
# 32  Execution(execId='0000e22a.616a8f64.01.01', ti...
# 33  Execution(execId='0000e22a.616a8fa2.01.01', ti...
# 34  Execution(execId='0000e0d5.6176e3d6.01.01', ti...
# 35  Execution(execId='0000e0d5.6176e3ff.01.01', ti...
#
#                                      commissionReport  \
# 0   CommissionReport(execId='0001911f.611d8b4b.01....
# 1   CommissionReport(execId='00013d66.611e37cc.01....
# 2   CommissionReport(execId='00012dbf.611e325b.01....
# 3   CommissionReport(execId='00012dbf.611e3682.01....
# 4   CommissionReport(execId='00013d04.611e216e.01....
# 5   CommissionReport(execId='00013800.611e6d71.01....
# 6   CommissionReport(execId='00012dc6.611e3e3f.01....
# 7   CommissionReport(execId='0001911f.611d8c29.01....
# 8   CommissionReport(execId='0001911f.611d8d3e.01....
# 9   CommissionReport(execId='0001911f.611d8d4b.01....
# 10  CommissionReport(execId='0001911f.611d8e18.01....
# 11  CommissionReport(execId='0001911f.611d8e61.01....
# 12  CommissionReport(execId='0001911f.611d8e7c.01....
# 13  CommissionReport(execId='0001911f.611d8f09.01....
# 14  CommissionReport(execId='0001911f.611d8f1a.01....
# 15  CommissionReport(execId='0001911f.611d8f8e.01....
# 16  CommissionReport(execId='0001911f.611d9005.01....
# 17  CommissionReport(execId='0001911f.611d9006.01....
# 18  CommissionReport(execId='0001911f.611d9026.01....
# 19  CommissionReport(execId='0001911f.611d9055.01....
# 20  CommissionReport(execId='0001911f.611d9286.01....
# 21  CommissionReport(execId='0001911f.611d9306.01....
# 22  CommissionReport(execId='0001911f.611d9399.01....
# 23  CommissionReport(execId='0001911f.611d9dd2.01....
# 24  CommissionReport(execId='0001911f.611d9e09.01....
# 25  CommissionReport(execId='0000ddc2.611e9227.01....
# 26  CommissionReport(execId='0000e22a.616a85b3.01....
# 27  CommissionReport(execId='0000e22a.616a8614.01....
# 28  CommissionReport(execId='0000e0d5.6175855b.01....
# 29  CommissionReport(execId='0000e0d5.61758637.01....
# 30  CommissionReport(execId='0000e0d5.61758d71.01....
# 31  CommissionReport(execId='0000e0d5.61758d85.01....
# 32  CommissionReport(execId='0000e22a.616a8f64.01....
# 33  CommissionReport(execId='0000e22a.616a8fa2.01....
# 34  CommissionReport(execId='0000e0d5.6176e3d6.01....
# 35  CommissionReport(execId='0000e0d5.6176e3ff.01....
#
#                         time
# 0  2021-08-19 13:26:53+00:00
# 1  2021-08-19 13:30:01+00:00
# 2  2021-08-19 13:30:02+00:00
# 3  2021-08-19 13:30:02+00:00
# 4  2021-08-19 13:30:03+00:00
# 5  2021-08-19 13:30:03+00:00
# 6  2021-08-19 13:30:06+00:00
# 7  2021-08-19 13:32:24+00:00
# 8  2021-08-19 13:37:48+00:00
# 9  2021-08-19 13:37:58+00:00
# 10 2021-08-19 13:43:27+00:00
# 11 2021-08-19 13:45:15+00:00
# 12 2021-08-19 13:46:09+00:00
# 13 2021-08-19 13:49:24+00:00
# 14 2021-08-19 13:49:53+00:00
# 15 2021-08-19 13:54:39+00:00
# 16 2021-08-19 14:00:37+00:00
# 17 2021-08-19 14:00:37+00:00
# 18 2021-08-19 14:01:15+00:00
# 19 2021-08-19 14:02:00+00:00
# 20 2021-08-19 14:26:24+00:00
# 21 2021-08-19 14:31:47+00:00
# 22 2021-08-19 14:39:33+00:00
# 23 2021-08-19 18:35:02+00:00
# 24 2021-08-19 18:40:45+00:00
# 25 2021-08-19 19:59:00+00:00
# 26 2021-08-19 13:30:00+00:00
# 27 2021-08-19 13:30:01+00:00
# 28 2021-08-19 13:30:01+00:00
# 29 2021-08-19 13:30:05+00:00
# 30 2021-08-19 13:30:26+00:00
# 31 2021-08-19 13:30:26+00:00
# 32 2021-08-19 13:30:27+00:00
# 33 2021-08-19 13:30:27+00:00
# 34 2021-08-19 19:59:00+00:00
# 35 2021-08-19 19:59:00+00:00

# %%
def Tradesdf(FillsDF):
    df=pd.DataFrame()
    df['account']=[execution.acctNumber for execution in FillsDF["execution"]]
    df['symbol']=[contract.symbol for contract in FillsDF["contract"]]
    df['action']=[execution.side for execution in FillsDF["execution"]]
    df['size']=[execution.shares for execution in FillsDF["execution"]]
    df['price']=[execution.price for execution in FillsDF["execution"]]
    df['commission']=[commission.commission for commission in FillsDF["commissionReport"]]
    df['time'] = pd.to_datetime(FillsDF['time'])
    df['orderRef'] = [execution.orderRef for execution in FillsDF["execution"]]
    df['secType']=[contract.secType for contract in FillsDF["contract"]]
    return df

# %%
try:
    AllFills = Tradesdf(TradeFillsDF) #returns error if no trades were executed today...
except:
    AllFills = []
AllFills
# Out:
#      account symbol action  size     price  commission  \
# 0    U950688    MYM    BOT   1.0  34643.00    0.520000
# 1    U538814   ADBE    BOT   6.0    624.88    1.000000
# 2    U538814    EFX    SLD  13.0    252.64    1.018297
# 3    U538814    DXC    SLD  38.0     36.00    1.011499
# 4    U950688   DOCU    BOT  11.0    283.57    1.000000
# 5    U538814   POOL    SLD   6.0    475.55    1.015266
# 6    U538814    NKE    BOT  22.0    166.96    1.000000
# 7    U950688    MYM    SLD   1.0  34733.00    0.520000
# 8    U950688    MYM    SLD   1.0  34748.00    0.520000
# 9    U950688    MYM    BOT   1.0  34727.00    0.520000
# 10   U950688    MYM    BOT   1.0  34779.00    0.520000
# 11   U950688    MYM    SLD   2.0  34756.00    1.040000
# 12   U950688    MYM    SLD   1.0  34805.00    0.520000
# 13   U950688    MYM    BOT   1.0  34775.00    0.520000
# 14   U950688    MYM    BOT   1.0  34773.00    0.520000
# 15   U950688    MYM    BOT   1.0  34835.00    0.520000
# 16   U950688    MYM    SLD   1.0  34801.00    0.520000
# 17   U950688    MYM    SLD   1.0  34801.00    0.520000
# 18   U950688    MYM    SLD   1.0  34832.00    0.520000
# 19   U950688    MYM    SLD   1.0  34863.00    0.520000
# 20   U950688    MYM    BOT   1.0  34818.00    0.520000
# 21   U950688    MYM    BOT   1.0  34798.00    0.520000
# 22   U950688    MYM    BOT   1.0  34729.00    0.520000
# 23   U950688    MYM    SLD   1.0  34704.00    0.520000
# 24   U950688    MYM    BOT   1.0  34694.00    0.520000
# 25   U950688   ANSS    SLD   8.0    357.58    1.015541
# 26  DU970594   XLNX    BOT  21.0    140.90    0.417457
# 27  DU970594   KLAC    BOT   9.0    315.00    0.333157
# 28  DU970594   ALGN    BOT   4.0    671.03    0.363057
# 29  DU970594   CDNS    BOT  20.0    147.83    0.312257
# 30  DU970594   ASML    BOT   4.0    763.25    0.362457
# 31  DU970594   DOCU    BOT  11.0    284.71    0.385457
# 32  DU970594   NXPI    BOT  15.0    200.99    0.353257
# 33  DU970594   MRVL    BOT  52.0     57.54    0.516657
# 34  DU970594   ANSS    SLD   8.0    357.56    0.367398
# 35  DU970594   CDNS    SLD  20.0    153.10    0.432253
#
#                         time secType
# 0  2021-08-19 13:26:53+00:00     FUT
# 1  2021-08-19 13:30:01+00:00     STK
# 2  2021-08-19 13:30:02+00:00     STK
# 3  2021-08-19 13:30:02+00:00     STK
# 4  2021-08-19 13:30:03+00:00     STK
# 5  2021-08-19 13:30:03+00:00     STK
# 6  2021-08-19 13:30:06+00:00     STK
# 7  2021-08-19 13:32:24+00:00     FUT
# 8  2021-08-19 13:37:48+00:00     FUT
# 9  2021-08-19 13:37:58+00:00     FUT
# 10 2021-08-19 13:43:27+00:00     FUT
# 11 2021-08-19 13:45:15+00:00     FUT
# 12 2021-08-19 13:46:09+00:00     FUT
# 13 2021-08-19 13:49:24+00:00     FUT
# 14 2021-08-19 13:49:53+00:00     FUT
# 15 2021-08-19 13:54:39+00:00     FUT
# 16 2021-08-19 14:00:37+00:00     FUT
# 17 2021-08-19 14:00:37+00:00     FUT
# 18 2021-08-19 14:01:15+00:00     FUT
# 19 2021-08-19 14:02:00+00:00     FUT
# 20 2021-08-19 14:26:24+00:00     FUT
# 21 2021-08-19 14:31:47+00:00     FUT
# 22 2021-08-19 14:39:33+00:00     FUT
# 23 2021-08-19 18:35:02+00:00     FUT
# 24 2021-08-19 18:40:45+00:00     FUT
# 25 2021-08-19 19:59:00+00:00     STK
# 26 2021-08-19 13:30:00+00:00     STK
# 27 2021-08-19 13:30:01+00:00     STK
# 28 2021-08-19 13:30:01+00:00     STK
# 29 2021-08-19 13:30:05+00:00     STK
# 30 2021-08-19 13:30:26+00:00     STK
# 31 2021-08-19 13:30:26+00:00     STK
# 32 2021-08-19 13:30:27+00:00     STK
# 33 2021-08-19 13:30:27+00:00     STK
# 34 2021-08-19 19:59:00+00:00     STK
# 35 2021-08-19 19:59:00+00:00     STK

# %%
try:
    HvRSIFills = AllFills.loc[AllFills['secType']=='STK'].drop(['secType'], axis=1)
except:
    HvRSIFills = []
HvRSIFills
# Out:
#      account symbol action  size   price  commission                      time
# 1    U538814   ADBE    BOT   6.0  624.88    1.000000 2021-08-19 13:30:01+00:00
# 2    U538814    EFX    SLD  13.0  252.64    1.018297 2021-08-19 13:30:02+00:00
# 3    U538814    DXC    SLD  38.0   36.00    1.011499 2021-08-19 13:30:02+00:00
# 4    U950688   DOCU    BOT  11.0  283.57    1.000000 2021-08-19 13:30:03+00:00
# 5    U538814   POOL    SLD   6.0  475.55    1.015266 2021-08-19 13:30:03+00:00
# 6    U538814    NKE    BOT  22.0  166.96    1.000000 2021-08-19 13:30:06+00:00
# 25   U950688   ANSS    SLD   8.0  357.58    1.015541 2021-08-19 19:59:00+00:00
# 26  DU970594   XLNX    BOT  21.0  140.90    0.417457 2021-08-19 13:30:00+00:00
# 27  DU970594   KLAC    BOT   9.0  315.00    0.333157 2021-08-19 13:30:01+00:00
# 28  DU970594   ALGN    BOT   4.0  671.03    0.363057 2021-08-19 13:30:01+00:00
# 29  DU970594   CDNS    BOT  20.0  147.83    0.312257 2021-08-19 13:30:05+00:00
# 30  DU970594   ASML    BOT   4.0  763.25    0.362457 2021-08-19 13:30:26+00:00
# 31  DU970594   DOCU    BOT  11.0  284.71    0.385457 2021-08-19 13:30:26+00:00
# 32  DU970594   NXPI    BOT  15.0  200.99    0.353257 2021-08-19 13:30:27+00:00
# 33  DU970594   MRVL    BOT  52.0   57.54    0.516657 2021-08-19 13:30:27+00:00
# 34  DU970594   ANSS    SLD   8.0  357.56    0.367398 2021-08-19 19:59:00+00:00
# 35  DU970594   CDNS    SLD  20.0  153.10    0.432253 2021-08-19 19:59:00+00:00

# %%
#check for exits that were missed at market close - will manage any open positions that are not in omit list
HvRSISells=0
HvRSIExits=[]
for item in HvRSIHoldings:
    if closes.iloc[-1][item]>highs.iloc[-2][item]:
        print (item, "closed today at", closes.iloc[-1][item], "above", highs.iloc[-2][item])
        HvRSIExits.append(item)
        HvRSISells+=1
    else:
        print ("count days for", item)
        print (item, "must close above", highs.iloc[-1][item])
HvRSIExits
# Out:
# count days for XLNX
# XLNX must close above 144.43
# count days for MRVL
# MRVL must close above 59.425
# count days for ASML
# ASML must close above 784.01
# count days for KLAC
# KLAC must close above 323.6
# count days for ALGN
# ALGN must close above 685.525
# count days for DOCU
# DOCU must close above 291.39
# count days for CPRT
# CPRT must close above 137.91
# count days for NXPI
# NXPI must close above 203.42
# []

# %%
#need to check for positions that should have closed but didn't and send market on open orders...

# %%
OrderSent=[]

# %%
# implement orderRef=str to track orders and retain information for database

# %%
#send exit orders- will manage any open positions that are not in omit list
ExitTime = NextTradeDay+' 15:59:00'
for item in HvRSIHoldings:
    if item not in HvRSIExits: #prevents sending duplicate orders
        ticker= Stock(item, 'SMART', 'USD')
        assert len(ib.reqContractDetails(ticker)) == 1
        ib.qualifyContracts(ticker)
        size=abs(PaperHoldings.loc[item]['position'])
        if closes.iloc[-1][item]>highs.iloc[-2][item]:
            order = MarketOrder('SELL', totalQuantity=size, account=TradeAccount, orderRef="HvRSIOpenSell")
        else:
            order = MarketOrder('SELL', totalQuantity=size, account=TradeAccount, orderRef="HvRSICloseSell")
            order.conditions = [PriceCondition(conId=ticker.conId, exch="SMART", isMore=True, price=highs.iloc[-1][item]), TimeCondition(isMore=True, time=ExitTime)]
        print(ticker, order, size)
        trade = ib.placeOrder(ticker, order)
        OrderSent.append(order)
        ib.sleep(3)
# Out:
# Stock(conId=276222, symbol='XLNX', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='XLNX', tradingClass='NMS') MarketOrder(action='SELL', orderRef='HvRSICloseSell', account='DU970594', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=144.43, conId=276222, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00')]) 21.0
# Stock(conId=483492393, symbol='MRVL', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='MRVL', tradingClass='NMS') MarketOrder(action='SELL', orderRef='HvRSICloseSell', account='DU970594', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=59.425, conId=483492393, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00')]) 52.0
# Stock(conId=117902840, symbol='ASML', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='ASML', tradingClass='NMS') MarketOrder(action='SELL', orderRef='HvRSICloseSell', account='DU970594', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=784.01, conId=117902840, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00')]) 4.0
# Stock(conId=270957, symbol='KLAC', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='KLAC', tradingClass='NMS') MarketOrder(action='SELL', orderRef='HvRSICloseSell', account='DU970594', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=323.6, conId=270957, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00')]) 9.0
# Stock(conId=11459264, symbol='ALGN', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='ALGN', tradingClass='NMS') MarketOrder(action='SELL', orderRef='HvRSICloseSell', account='DU970594', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=685.525, conId=11459264, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00')]) 4.0
# Stock(conId=316073742, symbol='DOCU', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='DOCU', tradingClass='NMS') MarketOrder(action='SELL', orderRef='HvRSICloseSell', account='DU970594', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=291.39, conId=316073742, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00')]) 11.0
# Stock(conId=4728523, symbol='CPRT', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='CPRT', tradingClass='NMS') MarketOrder(action='SELL', orderRef='HvRSICloseSell', account='DU970594', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=137.91, conId=4728523, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00')]) 21.0
# Stock(conId=77791077, symbol='NXPI', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='NXPI', tradingClass='NMS') MarketOrder(action='SELL', orderRef='HvRSICloseSell', account='DU970594', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=203.42, conId=77791077, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00')]) 15.0

# %%
#send new orders for any empty slots
RemainingHold=len(HvRSIHoldings)-HvRSISells
PotentialSlots = 10-RemainingHold
SlotsToFill = min(PotentialSlots,len(NewHvRSI))
print (SlotsToFill)

for item in NewHvRSI:
    if SlotsToFill>0:
        ticker= Stock(item, 'SMART', 'USD')
        #assert len(ib.reqContractDetails(ticker)) == 1
        ib.qualifyContracts(ticker)
        size=abs(HvRSIQQQ.loc[item]['Size'])
        price = HvRSIQQQ.loc[item]['close']
        parent = LimitOrder('BUY', totalQuantity=size, lmtPrice = price, account=TradeAccount, orderId=ib.client.getReqId(), transmit=False, orderRef="HvRSIParent")
        #need to add child order with conditions to close on same day
        child = MarketOrder('SELL', totalQuantity=size, account=TradeAccount, orderId=ib.client.getReqId(), transmit=True, parentId=parent.orderId, orderRef="HvRSIChild")
        child.conditions = [PriceCondition(conId=ticker.conId, exch="SMART", isMore=True, price=highs.iloc[-1][item]), TimeCondition(isMore=True, time=ExitTime)]

        print(ticker, parent, size, child)
        trade1 = ib.placeOrder(ticker, parent)
        OrderSent.append(parent)
        ib.sleep(3)
        trade2 = ib.placeOrder(ticker, child)
        OrderSent.append(child)
        ib.sleep(3)
        SlotsToFill-=1
        print (SlotsToFill)
# Out:
# 0

# %%
RunSPY = input ("Run SPY?")
if RunSPY == "y":
    pass
else:
    ib.disconnect()
# Out:
# Run SPY?y

# %%
NewHvRSI = [item for item in HvRSISpy.index if item not in HvRSIHoldings]
NewHvRSI
# Out:
# ['UAA',
#  'UA',
#  'IPG',
#  'TXT',
#  'PPG',
#  'WAB',
#  'J',
#  'TDY',
#  'TGT',
#  'ADM',
#  'IFF',
#  'CNP']

# %%
#send new orders for any empty slots
RemainingHold=len(HvRSIHoldings)-HvRSISells
PotentialSlots = 10-RemainingHold
print(PotentialSlots,len(NewHvRSI))
SlotsToFill = int(input ("how many to fill? "))
print (SlotsToFill)
# Out:
# 2 12
# how many to fill? 3
# 3

# %%
for item in NewHvRSI:
    if SlotsToFill>0:
        ticker= Stock(item, 'SMART', 'USD')
        #assert len(ib.reqContractDetails(ticker)) == 1
        ib.qualifyContracts(ticker)
        size=abs(HvRSISpy.loc[item]['Size'])
        price = HvRSISpy.loc[item]['close']
        parent = LimitOrder('BUY', totalQuantity=size, lmtPrice = price, account=TradeAccount, orderId=ib.client.getReqId(), transmit=False, orderRef="HvRSISPYParent")
        #need to add child order with conditions to close on same day
        child = MarketOrder('SELL', totalQuantity=size, account=TradeAccount, orderId=ib.client.getReqId(), transmit=True, parentId=parent.orderId, orderRef="HvRSIChild")
        child.conditions = [PriceCondition(conId=ticker.conId, exch="SMART", isMore=True, price=highs.iloc[-1][item]), TimeCondition(isMore=True, time=ExitTime)]

        print(ticker, parent, size, child)
        trade1 = ib.placeOrder(ticker, parent)
        OrderSent.append(parent)
        ib.sleep(3)
        trade2 = ib.placeOrder(ticker, child)
        OrderSent.append(child)
        ib.sleep(3)
        SlotsToFill-=1
        print (SlotsToFill)
# Out:
# Stock(conId=36786278, symbol='UAA', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='UAA', tradingClass='UAA') LimitOrder(orderId=88159708, action='BUY', orderRef='HvRSISPYParent', transmit=False, account='DU970594') 133.0 MarketOrder(orderId=88159709, action='SELL', orderRef='HvRSIChild', parentId=88159708, account='DU970594', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=23.205, conId=36786278, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00')])
# 2
# Stock(conId=225590118, symbol='UA', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='UA', tradingClass='UA') LimitOrder(orderId=88159711, action='BUY', orderRef='HvRSISPYParent', transmit=False, account='DU970594') 157.0 MarketOrder(orderId=88159712, action='SELL', orderRef='HvRSIChild', parentId=88159711, account='DU970594', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=19.595, conId=225590118, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00')])
# 1
# Stock(conId=8514, symbol='IPG', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='IPG', tradingClass='IPG') LimitOrder(orderId=88159714, action='BUY', orderRef='HvRSISPYParent', transmit=False, account='DU970594') 83.0 MarketOrder(orderId=88159715, action='SELL', orderRef='HvRSIChild', parentId=88159714, account='DU970594', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=36.919, conId=8514, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00')])
# 0

# %%
OrderSent
# Out:
# [MarketOrder(orderId=88159685, permId=1340150601, action='SELL', totalQuantity=21.0, lmtPrice=0.0, auxPrice=0.0, tif='DAY', ocaType=3, orderRef='HvRSICloseSell', trailStopPrice=140.5, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU970594', clearingIntent='IB', adjustedOrderType='None', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=144.43, conId=276222, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00 EST')], cashQty=0.0, dontUseAutoPriceForHedge=True),
#  MarketOrder(orderId=88159688, permId=1340150602, action='SELL', totalQuantity=52.0, lmtPrice=0.0, auxPrice=0.0, tif='DAY', ocaType=3, orderRef='HvRSICloseSell', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU970594', clearingIntent='IB', adjustedOrderType='None', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=59.425, conId=483492393, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00 EST')], cashQty=0.0, dontUseAutoPriceForHedge=True),
#  MarketOrder(orderId=88159691, permId=1340150603, action='SELL', totalQuantity=4.0, lmtPrice=0.0, auxPrice=0.0, tif='DAY', ocaType=3, orderRef='HvRSICloseSell', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU970594', clearingIntent='IB', adjustedOrderType='None', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=784.01, conId=117902840, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00 EST')], cashQty=0.0, dontUseAutoPriceForHedge=True),
#  MarketOrder(orderId=88159694, permId=1340150604, action='SELL', totalQuantity=9.0, lmtPrice=0.0, auxPrice=0.0, tif='DAY', ocaType=3, orderRef='HvRSICloseSell', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU970594', clearingIntent='IB', adjustedOrderType='None', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=323.6, conId=270957, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00 EST')], cashQty=0.0, dontUseAutoPriceForHedge=True),
#  MarketOrder(orderId=88159697, permId=1340150605, action='SELL', totalQuantity=4.0, lmtPrice=0.0, auxPrice=0.0, tif='DAY', ocaType=3, orderRef='HvRSICloseSell', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU970594', clearingIntent='IB', adjustedOrderType='None', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=685.525, conId=11459264, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00 EST')], cashQty=0.0, dontUseAutoPriceForHedge=True),
#  MarketOrder(orderId=88159700, permId=1340150606, action='SELL', totalQuantity=11.0, lmtPrice=0.0, auxPrice=0.0, tif='DAY', ocaType=3, orderRef='HvRSICloseSell', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU970594', clearingIntent='IB', adjustedOrderType='None', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=291.39, conId=316073742, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00 EST')], cashQty=0.0, dontUseAutoPriceForHedge=True),
#  MarketOrder(orderId=88159703, permId=1340150607, action='SELL', totalQuantity=21.0, lmtPrice=0.0, auxPrice=0.0, tif='DAY', ocaType=3, orderRef='HvRSICloseSell', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU970594', clearingIntent='IB', adjustedOrderType='None', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=137.91, conId=4728523, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00 EST')], cashQty=0.0, dontUseAutoPriceForHedge=True),
#  MarketOrder(orderId=88159706, permId=1340150608, action='SELL', totalQuantity=15.0, lmtPrice=0.0, auxPrice=0.0, tif='DAY', ocaType=3, orderRef='HvRSICloseSell', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU970594', clearingIntent='IB', adjustedOrderType='None', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=203.42, conId=77791077, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00 EST')], cashQty=0.0, dontUseAutoPriceForHedge=True),
#  LimitOrder(orderId=88159708, permId=1340150609, action='BUY', totalQuantity=133.0, lmtPrice=22.61, auxPrice=0.0, tif='DAY', ocaType=3, orderRef='HvRSISPYParent', trailStopPrice=23.61, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU970594', clearingIntent='IB', adjustedOrderType='None', cashQty=0.0, dontUseAutoPriceForHedge=True),
#  MarketOrder(orderId=88159709, permId=1340150610, action='SELL', totalQuantity=133.0, lmtPrice=0.0, auxPrice=0.0, tif='DAY', ocaGroup='1340150609', ocaType=3, orderRef='HvRSIChild', parentId=88159708, trailStopPrice=21.8, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU970594', clearingIntent='IB', adjustedOrderType='None', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=23.205, conId=36786278, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00 EST')], cashQty=0.0, dontUseAutoPriceForHedge=True),
#  LimitOrder(orderId=88159711, permId=1340150611, action='BUY', totalQuantity=157.0, lmtPrice=19.05, auxPrice=0.0, tif='DAY', ocaType=3, orderRef='HvRSISPYParent', trailStopPrice=20.05, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU970594', clearingIntent='IB', adjustedOrderType='None', cashQty=0.0, dontUseAutoPriceForHedge=True),
#  MarketOrder(orderId=88159712, permId=1340150612, action='SELL', totalQuantity=157.0, lmtPrice=0.0, auxPrice=0.0, tif='DAY', ocaGroup='1340150611', ocaType=3, orderRef='HvRSIChild', parentId=88159711, trailStopPrice=18.55, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU970594', clearingIntent='IB', adjustedOrderType='None', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=19.595, conId=225590118, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00 EST')], cashQty=0.0, dontUseAutoPriceForHedge=True),
#  LimitOrder(orderId=88159714, permId=1340150613, action='BUY', totalQuantity=83.0, lmtPrice=36.1, auxPrice=0.0, tif='DAY', ocaType=3, orderRef='HvRSISPYParent', trailStopPrice=37.1, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU970594', clearingIntent='IB', adjustedOrderType='None', cashQty=0.0, dontUseAutoPriceForHedge=True),
#  MarketOrder(orderId=88159715, permId=1340150614, action='SELL', totalQuantity=83.0, lmtPrice=0.0, auxPrice=0.0, tif='DAY', ocaGroup='1340150613', ocaType=3, orderRef='HvRSIChild', parentId=88159714, trailStopPrice=34.68, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU970594', clearingIntent='IB', adjustedOrderType='None', conditions=[PriceCondition(condType=1, conjunction='a', isMore=True, price=36.919, conId=8514, exch='SMART', triggerMethod=0), TimeCondition(condType=3, conjunction='a', isMore=True, time='20210820 15:59:00 EST')], cashQty=0.0, dontUseAutoPriceForHedge=True)]

# %%
outfile = open(f"StockReports/Trades/OrderSent{Today}",'wb')
pickle.dump(OrderSent,outfile)
outfile.close()

# %%
#still to consider - Tracking length of time for entries and sells
ib.disconnect()
